# %% [markdown]
# ### 條狀圖

# %%
import matplotlib.pyplot as plt
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
subject = ['appale','banana','orange','tomato','guava']

plt.bar(index, values)
plt.xticks(index, subject)
print(plt.xticks())
for idx,i in enumerate(index):
    plt.annotate(str(values[idx]),(i-0.2,values[idx]+100))
# Out:
# (array([3, 4, 5, 6, 7]), [Text(3, 0, 'appale'), Text(4, 0, 'banana'), Text(5, 0, 'orange'), Text(6, 0, 'tomato'), Text(7, 0, 'guava')])

# %%
for idx,i in enumerate(index):
    print(i)
    print(idx)
    print("=====")
# Out:
# 3
# 0
# =====
# 4
# 1
# =====
# 5
# 2
# =====
# 6
# 3
# =====
# 7
# 4
# =====

# %%
import matplotlib.pyplot as plt
import numpy as np
index = np.array([3, 4, 5, 6, 7])
values1 = [5000, 6000, 7000, 8000, 9000]
values2 = [3000, 4000, 5000, 6000, 7000]
values3 = [4000, 5000, 6000, 7000, 8000]

subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values1,color='r',width=0.3)
plt.bar(index+0.3, values2,color='b',width=0.3)
plt.bar(index-0.3, values3,color='g',width=0.3)
plt.xticks(index, subject)


xmin, xmax, ymin, ymax = plt.axis()
xmin -= 0.2
xmax += 0.2
ymin = 1000
ymax += 1000
_ = plt.axis(xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)

# %%
import matplotlib.pyplot as plt
import numpy as np
index = np.array([3, 4, 5, 6, 7])
values1 = [5000, 6000, 7000, 8000, 9000]
values2 = [3000, 4000, 5000, 6000, 7000]
values3 = [4000, 5000, 6000, 7000, 8000]

subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values1,color='r',width=0.3)
plt.bar(index+0.3, values2,color='b',width=0.3)
plt.bar(index-0.3, values3,color='g',width=0.3)
plt.xticks(index, subject)


xmin, xmax, ymin, ymax = plt.axis()
xmin -= 0.2
xmax += 0.2
ymin = 1000
ymax += 1000
_ = plt.axis(xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)import matplotlib.pyplot as plt
import numpy as np
index = [3, 4, 5, 6, 7]
values1 = [5000, 6000, 7000, 8000, 9000]
values2 = [3000, 4000, 5000, 6000, 7000]
values3 = [4000, 5000, 6000, 7000, 8000]
subject = ['appale','banana','orange','tomato','guava']

plt.bar(index, values1, color='r', width=0.3)
plt.bar(index+0.3, values2, color='g', width=0.3)
plt.bar(index-0.3, values3, color='b', width=0.3)
plt.xticks(index, subject)


xmin, xmax, ymin, ymax = plt.axis()
xmin -= 0.2
xmax += 0.2
ymin = 1000
ymax += 1000
plt.axis(xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       7 subject = ['appale','banana','orange','tomato','guava']
#       9 plt.bar(index, values1, color='r', width=0.3)
# ---> 10 plt.bar(index+0.3, values2, color='g', width=0.3)
#      11 plt.bar(index-0.3, values3, color='b', width=0.3)
#      12 plt.xticks(index, subject)
#
# TypeError: can only concatenate list (not "float") to list
