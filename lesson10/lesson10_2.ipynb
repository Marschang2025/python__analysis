# %% [markdown]
# ### python如何讀取students.csv
#
# ---
# python如何讀取students.csv
# 你可以使用 Python 內建的 csv 模組來讀取 students.csv，以下是簡單的範例：
#
# import csv
#
# with open('students.csv', newline='', encoding='utf-8') as csvfile:
#     reader = csv.DictReader(csvfile)  # 使用 DictReader 讀取成字典格式
#     for row in reader:
#         print(row)  # 每一列會是字典，鍵是欄位名稱
# 說明：
#
# open() 中指定 encoding='utf-8' 避免中文亂碼。
# csv.DictReader 會自動把 CSV 第一列當作欄位名稱，並將每列轉成字典。
# 你也可以用 csv.reader 讀成串列形式，但 DictReader 更適合有欄位標題的 CSV。
# 執行後，每一列會輸出類似：
#
# {'姓名': '錢欣潔', '國文': '100', '英文': '77', '數學': '59'}
# {'姓名': '許芳如', '國文': '98', '英文': '74', '數學': '99'}
# {'姓名': '陳怡伶', '國文': '54', '英文': '67', '數學': '79'}
# 這是讀取 CSV 檔案並取得每筆資料的標準作法[1][2][4][5]。

# %%
import csv
from csv import DictReader

with open('students.csv',encoding='utf-8',newline='') as csv_file:
    reader:DictReader = csv.DictReader(csv_file)
    students = list(reader)

students
# Out:
# [{'姓名': '龐皓芳', '國文': '96', '英文': '74', '數學': '69'},
#  {'姓名': '王人仰', '國文': '82', '英文': '61', '數學': '81'},
#  {'姓名': '陳俊憲', '國文': '83', '英文': '84', '數學': '76'},
#  {'姓名': '張慧君', '國文': '55', '英文': '84', '數學': '64'},
#  {'姓名': '郭淑枝', '國文': '96', '英文': '94', '數學': '81'},
#  {'姓名': '溫法堯', '國文': '74', '英文': '74', '數學': '58'},
#  {'姓名': '鞠冠宇', '國文': '53', '英文': '62', '數學': '80'},
#  {'姓名': '盧文啟', '國文': '69', '英文': '64', '數學': '98'},
#  {'姓名': '黃淑芬', '國文': '59', '英文': '85', '數學': '80'},
#  {'姓名': '蔡偉成', '國文': '55', '英文': '76', '數學': '89'},
#  {'姓名': '林佳人', '國文': '98', '英文': '72', '數學': '71'},
#  {'姓名': '柯宜臻', '國文': '95', '英文': '70', '數學': '51'},
#  {'姓名': '林怡偉', '國文': '70', '英文': '89', '數學': '70'},
#  {'姓名': '魏秋萍', '國文': '90', '英文': '52', '數學': '98'},
#  {'姓名': '尚偉倫', '國文': '78', '英文': '61', '數學': '52'},
#  {'姓名': '傅佳琳', '國文': '77', '英文': '67', '數學': '57'},
#  {'姓名': '陳筱涵', '國文': '51', '英文': '87', '數學': '79'},
#  {'姓名': '吳淑惠', '國文': '66', '英文': '71', '數學': '76'},
#  {'姓名': '柯韋成', '國文': '71', '英文': '94', '數學': '91'},
#  {'姓名': '洪阿惠', '國文': '56', '英文': '51', '數學': '85'},
#  {'姓名': '余丞苓', '國文': '75', '英文': '73', '數學': '50'},
#  {'姓名': '翁鈺婷', '國文': '51', '英文': '97', '數學': '96'},
#  {'姓名': '林群清', '國文': '85', '英文': '64', '數學': '77'},
#  {'姓名': '簡國瑋', '國文': '93', '英文': '70', '數學': '66'},
#  {'姓名': '郭致恬', '國文': '72', '英文': '96', '數學': '80'},
#  {'姓名': '林益妏', '國文': '56', '英文': '81', '數學': '97'},
#  {'姓名': '胡姿婷', '國文': '85', '英文': '71', '數學': '84'},
#  {'姓名': '陳孝邦', '國文': '77', '英文': '96', '數學': '51'},
#  {'姓名': '蔡至剛', '國文': '89', '英文': '79', '數學': '65'},
#  {'姓名': '王良斌', '國文': '56', '英文': '52', '數學': '82'},
#  {'姓名': '李蓉瑞', '國文': '81', '英文': '59', '數學': '83'},
#  {'姓名': '戚亨', '國文': '88', '英文': '88', '數學': '55'},
#  {'姓名': '楊少亮', '國文': '85', '英文': '69', '數學': '68'},
#  {'姓名': '劉昀天', '國文': '93', '英文': '82', '數學': '79'},
#  {'姓名': '葉志峰', '國文': '85', '英文': '84', '數學': '95'},
#  {'姓名': '李政白', '國文': '96', '英文': '69', '數學': '93'},
#  {'姓名': '趙家豪', '國文': '60', '英文': '64', '數學': '77'},
#  {'姓名': '楊易政', '國文': '98', '英文': '90', '數學': '53'},
#  {'姓名': '陳逸凡', '國文': '75', '英文': '76', '數學': '55'},
#  {'姓名': '陳向愛', '國文': '81', '英文': '94', '數學': '56'},
#  {'姓名': '金宜芳', '國文': '87', '英文': '100', '數學': '63'},
#  {'姓名': '謝貞妃', '國文': '80', '英文': '54', '數學': '80'},
#  {'姓名': '黃詩妃', '國文': '96', '英文': '55', '數學': '52'},
#  {'姓名': '楊建安', '國文': '82', '英文': '80', '數學': '83'},
#  {'姓名': '鄧淑娟', '國文': '81', '英文': '69', '數學': '89'},
#  {'姓名': '羅佩樺', '國文': '95', '英文': '88', '數學': '100'},
#  {'姓名': '周琬婷', '國文': '74', '英文': '76', '數學': '65'},
#  {'姓名': '周怡啟', '國文': '91', '英文': '90', '數學': '95'},
#  {'姓名': '楊韋廷', '國文': '51', '英文': '69', '數學': '59'},
#  {'姓名': '王明昇', '國文': '97', '英文': '57', '數學': '70'}]
