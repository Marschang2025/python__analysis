# %% [markdown]
# ### https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html
# plot(x, y, 'go--', linewidth=2, markersize=12)
# plot(x, y, color='green', marker='o', linestyle='dashed',
#      linewidth=2, markersize=12)

# %%
#標準寫法
import matplotlib.pyplot as plt

# 1.製作figure(畫布)
fig = plt.figure()

# 2.在1.的figure上製作一個axes(幾個圖表)
ax_1 = fig.add_subplot(1, 1, 1)

# 3.將圖的數據儲存在axes中
X = [0, 1, 2]
Y = [3, 4, 5]
ax_1.plot(X, Y)

# 4.顯示圖
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
X = [0, 3, 9]
Y = [3, 4, 5]
axes.plot(X,Y,color='green',marker='o',linestyle='dashed',linewidth=2,markersize=12)
plt.show()

# %% [markdown]
# ### axes1 = figure.add_subplot(1, 3, 1) 代表1個畫布裡有3個圖表的第1的

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(1, 3, 1)
axes2 = figure.add_subplot(1, 3, 2)
axes3 = figure.add_subplot(1, 3, 3)

axes1.set_title("plot1")
axes2.set_title("plot2")
axes3.set_title("plot3")
plt.show()

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\asus\miniconda3\envs\myenv\lib\site-packages (3.2)

# %%
import wget

wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

figure = plt.figure()
axes1 = figure.add_subplot(1, 3, 1)
axes2 = figure.add_subplot(1, 3, 2)
axes3 = figure.add_subplot(1, 3, 3)

axes1.set_title("圖表1")
axes2.set_title("圖表2")
axes3.set_title("圖表3")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

student1 = {'國文':78,'英文':80,'數學':92,'歷史':75,'探索':85}
student2 = {'國文':90,'英文':75,'數學':98,'歷史':65,'探索':75}
subjects = list(student1.keys())
stu1_values = list(student1.values())
stu2_values = list(student2.values())
subjects, stu1_values,stu2_values
# Out:
# (['國文', '英文', '數學', '歷史', '探索'], [78, 80, 92, 75, 85], [90, 75, 98, 65, 75])

# %%
#標準寫法
figure = plt.figure(figsize=(8, 5),dpi=240,facecolor='#cccccc')
axes = figure.add_subplot(1,1,1)
axes.set_title("學生分數")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.plot(subjects,stu1_values,marker='o',linestyle='-.')
plt.show()
plt.close()

# %%
#標準寫法
figure = plt.figure(figsize=(8, 5),dpi=240,facecolor='#cccccc')
axes = figure.add_subplot(1,1,1)
axes.set_title("學生分數")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.plot(subjects,stu1_values,marker='o',linestyle='-.',label="學生1")
axes.plot(subjects,stu2_values,marker='*',linestyle='-.',label="學生2")
axes.legend()
plt.show()
plt.close()

# %%
#標準寫法
figure = plt.figure(figsize=(8, 5),dpi=240,facecolor='#cccccc')
axes = figure.add_subplot(1,1,1)
axes.set_title("學生分數")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.plot(subjects,stu1_values,marker='o',linestyle='-.',label="學生1")
axes.plot(subjects,stu2_values,marker='o',linestyle='-.',label="學生2")
x_locations = axes.get_xticks()
y_locations = axes.get_yticks()
#print(axes.get_xticklabels())
#axes.set_xticklabels(['chinese', 'english', 'math', 'history', 'discover'])
axes.set_xlim(xmin=min(x_locations)-1,xmax=max(x_locations)+1)
axes.set_ylim(ymin=min(y_locations)-10,ymax=max(y_locations)+10)
axes.legend()
plt.show()
plt.close()

# %%
#標準寫法
figure = plt.figure(figsize=(8, 5),dpi=240,facecolor='#cccccc')
axes = figure.add_subplot(1,1,1)
axes.set_title("學生分數")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.plot(subjects,stu1_values,marker='o',linestyle='-.',label="學生1")
axes.plot(subjects,stu2_values,marker='o',linestyle='-.',label="學生2")
x_locations = axes.get_xticks()
y_locations = axes.get_yticks()
#print(axes.get_xticklabels())
#axes.set_xticklabels(['chinese', 'english', 'math', 'history', 'discover'])
axes.set_xlim(xmin=min(x_locations)-1,xmax=max(x_locations)+1)
axes.set_ylim(ymin=min(y_locations)-10,ymax=max(y_locations)+10)
for x in x_locations:
    axes.annotate(str(stu1_values[x]),(x,stu1_values[x]+1))
    axes.annotate(str(stu2_values[x]),(x,stu2_values[x]+1))
#axes.annotate("註解",(0,80))
axes.legend()
plt.show()
plt.close()

# %%
#標準寫法
figure = plt.figure(figsize=(8, 5),dpi=240,facecolor='#cccccc')
axes = figure.add_subplot(1,1,1)
axes.set_title("學生分數")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.plot(subjects,stu1_values,marker='o',linestyle='-.',label="學生1")
axes.plot(subjects,stu2_values,marker='o',linestyle='-.',label="學生2")
axes.hlines(85,xmin=-1,xmax=6,colors='red',linestyles='--') #標準線應用
x_locations = axes.get_xticks()
y_locations = axes.get_yticks()
#print(axes.get_xticklabels())
#axes.set_xticklabels(['chinese', 'english', 'math', 'history', 'discover'])
axes.set_xlim(xmin=min(x_locations)-1,xmax=max(x_locations)+1)
axes.set_ylim(ymin=min(y_locations)-10,ymax=max(y_locations)+10)

for x in x_locations:
    axes.annotate(str(stu1_values[x]),(x,stu1_values[x]+1))
    axes.annotate(str(stu2_values[x]),(x,stu2_values[x]+1))
#axes.annotate("註解",(0,80))
axes.legend()
axes.grid(axis='y')
plt.show()
plt.close()
